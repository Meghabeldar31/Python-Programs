# %% [markdown]
# Logarithm : A logarithm is the power(exponent) to which a base must be raised to obtain a given number.
#
# Logarithm base 2

# %%
num=int(input("Enter a number :"))
count=0
while num>1:
  num=num//2
  count=count+1
print("log base 2=",count)
# Out:
# Enter a number :4
# log base 2= 2

# %% [markdown]
# Logarithm base 10

# %%
num=int(input("Enter a number :"))
count=0
while num>1:
  num=num//10
  count=count+1
print("log base 10=",count)
# Out:
# Enter a number :100
# log base 10= 2

# %% [markdown]
# Logarithm base 5

# %%
num=int(input("Enter a number :"))
count=0
while num>1:
  num=num//5
  count=count+1
print("log base 5=",count)
# Out:
# Enter a number :100
# log base 5= 3

# %% [markdown]
# Logarithm base 20

# %%
num=int(input("Enter a number :"))
count=0
while num>1:
  num=num//20
  count=count+1
print("log base 20=",count)
# Out:
# Enter a number :1000
# log base 20= 3

# %% [markdown]
# Logarithm base 40

# %%
num=int(input("Enter a number :"))
count=0
while num>1:
  num=num//40
  count=count+1
print("log base 40=",count)
# Out:
# Enter a number :1000
# log base 40= 2
